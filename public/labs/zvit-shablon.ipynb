# %% [markdown]
# # Лабораторна робота № _ · _назва_
#
# **Курс:** Інтелектуальні системи аналізу медичних зображень та комп’ютерної діагностики · КПІ ім. Ігоря Сікорського
#
# | Учасник | ПІБ, група | За що відповідав | Комірки |
# |---|---|---|---|
# | A |  |  |  |
# | B |  |  |  |
# | C |  |  |  |
#
# _Навчальна робота на відкритих деідентифікованих даних; результати не є медичними рекомендаціями._

# %% [markdown]
# ## Мета
#
# _Перепишіть мету з методичних вказівок і додайте одне речення про те, що саме робила ваша бригада._

# %% [markdown]
# ## Дані
#
# _Для кожного набору: звідки завантажено (посилання), обсяг, скільки пацієнтів і знімків використано, умови використання й обов’язкове посилання на статтю._
#
# | Набір | Джерело | Обсяг | Пацієнтів / знімків | Умови використання |
# |---|---|---|---|---|
# |  |  |  |  |  |

# %%
import os, random
import numpy as np
import matplotlib.pyplot as plt

# Зерна фіксуємо явно: без них результат не відтворюється,
# а чек-лист відтворюваності вимагає саме списку зерен.
SEEDS = [0, 1, 2, 3, 4]
SEED = SEEDS[0]
random.seed(SEED)
np.random.seed(SEED)
try:
    import torch
    torch.manual_seed(SEED)
    torch.set_num_threads(os.cpu_count() or 1)
except ImportError:
    pass

# %% [markdown]
# ## Хід виконання
#
# _Кожен пункт «Порядку виконання» — окремий підрозділ. Код того учасника, який
# за пункт відповідає, лишається у своїх комірках._

# %% [markdown]
# ### [A] _пункт 1_

# %%
# код учасника A

# %% [markdown]
# ### [B] _пункт 2_

# %%
# код учасника B

# %% [markdown]
# ### [C] _пункт 3_

# %%
# код учасника C

# %% [markdown]
# ## Результати
#
# _Таблиці й рисунки, а не переказ. Кожна таблиця підписана: що в клітинках, в яких одиницях, за яких умов виміряно. На кожному графіку підписано, що є лінією, а що — затіненою смугою._

# %%
# підсумкові таблиці й графіки

# %% [markdown]
# ## Аналіз
#
# _Поясніть, **чому** вийшло саме так. Це головний розділ: таблицю з числами
# може зробити кожен, а пояснення різниці — ні. Якщо результат розійшовся
# з очікуваним, напишіть про це чесно й висуньте припущення про причину._

# %% [markdown]
# ## Чек-лист відтворюваності
#
# Заповніть, це частина оцінки.
#
# - [ ] версії Python і бібліотек (комірка нижче):
# - [ ] зерна генераторів:
# - [ ] поділ на train / validation / test **на рівні пацієнта**; кількість пацієнтів і знімків у кожній частині:
# - [ ] поріг і гіперпараметри обрано на validation, test використано один раз:
# - [ ] кількість незалежних запусків (не менше п’яти там, де є випадковість); у звіті — середнє й розкид:
# - [ ] повна таблиця гіперпараметрів:
# - [ ] ноутбук виконується командою *Restart & Run All* без помилок і ручних правок:

# %%
import sys, platform, importlib
print("Python    ", sys.version.split()[0], "|", platform.platform())
for name in ["numpy", "pandas", "pydicom", "nibabel", "SimpleITK", "skimage", "sklearn", "torch", "torchvision", "monai"]:
    try:
        m = importlib.import_module(name)
        v = getattr(m, "__version__", None) or getattr(m, "Version_VersionString", lambda: "?")()
        print(f"{name:<10}", v)
    except ImportError:
        print(f"{name:<10}", "не встановлено")
print("зерна     ", SEEDS)

# %% [markdown]
# ## Висновки
#
# Три-п’ять пунктів. Кожен — перевірюване твердження **з числом**,
# а не «ознайомилися з форматом DICOM».
#
# 1.
# 2.
# 3.
